# %% [markdown]
# # 3D Lattice Vectors
#
# Enter three primary lattice vectors and adjust the lattice radius to render the generated 3D lattice dynamically.

# %%
from cells.lattice_visualizer import create_lattice_ui

create_lattice_ui()
