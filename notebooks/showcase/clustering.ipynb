# %%
from os import chdir, path
from pathlib import Path

chdir(Path(path.abspath('')).parent.parent)

from utils.algorithms.distributions import random_2d
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

_x=100
_y=100
_N=500

f = lambda x,y,N : np.exp(-0.01*((_x//2-x)**2+(_y//2-y)**2+(_N//2-N)**2))

r = random_2d(_x, _y, _N, f)

print(r.shape)

plt.imshow(r, interpolation="none")
plt.show()
