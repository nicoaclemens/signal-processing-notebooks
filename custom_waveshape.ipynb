# %% [markdown]
# # Custom Waveshape Synthesiser

# %%
from cells.play_audio_custom_wave import create_custom_wave_ui

create_custom_wave_ui()
# Out:
# VBox(children=(<widget.draw_widget.DrawWidget object at 0x000002100FFB2F00>, VBox(children=(HTML(value='<p sty…
