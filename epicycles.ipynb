# %% [markdown]
# # Fourier Epicycles
#
# Funktioniert nicht wirklich, abandoned
#
# Ein bild kann als ein Pfad in einem zweidimensionalem Raum dargestellt werden $f: \mathbb{R}->\mathbb{R}^2$. Wenn man die Fourier-transformation der x- und y-komponenten dieses Pfades berechnet kann man das Bild in einer sog. _Epizyklischen Animation_ zeichnen lassen.

# %%
from cells.epicycles import create_epicycles_ui

create_epicycles_ui(grid_size=64)
